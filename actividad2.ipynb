# %%
#INSTALAR LIBRERIAS
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install seaborn
# !pip install openpyxl

# %%
#Importamos librerías requeridas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Convertimos el dataset en dataframe
df= pd.read_csv("listings.csv")
df
# Out:
#                         id                                       listing_url  \
# 0                    27886                https://www.airbnb.com/rooms/27886
# 1                    28871                https://www.airbnb.com/rooms/28871
# 2                    29051                https://www.airbnb.com/rooms/29051
# 3                    44391                https://www.airbnb.com/rooms/44391
# 4                    47061                https://www.airbnb.com/rooms/47061
# ...                    ...                                               ...
# 10163  1437492870456891135  https://www.airbnb.com/rooms/1437492870456891135
# 10164  1437585511300942515  https://www.airbnb.com/rooms/1437585511300942515
# 10165  1437601466510408215  https://www.airbnb.com/rooms/1437601466510408215
# 10166  1437660079651924451  https://www.airbnb.com/rooms/1437660079651924451
# 10167  1438602403155395239  https://www.airbnb.com/rooms/1438602403155395239
#
# ...

# %%
#Verificamos información del DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10168 entries, 0 to 10167
# Data columns (total 79 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            10168 non-null  int64
#  1   listing_url                                   10168 non-null  object
#  2   scrape_id                                     10168 non-null  int64
#  3   last_scraped                                  10168 non-null  object
#  4   source                                        10168 non-null  object
#  5   name                                          10168 non-null  object
#  6   description                                   9859 non-null   object
#  7   neighborhood_overview                         5258 non-null   object
#  8   picture_url                                   10168 non-null  object
# ...

# %%
#Hacer una lsita de 50 columnas, las cuales debo de seleccionar con cuales me quedo
# y que otras depuro

# Lista de columnas a eliminar
columnas_remover = [
    'id', 'listing_url', 'scrape_id', 'source', 'picture_url',
    'host_id', 'host_url', 'host_thumbnail_url', 'host_picture_url',
    'description', 'neighborhood_overview', 'host_about', 'license',
    'calendar_updated', 'calendar_last_scraped',
    'availability_30', 'availability_60', 'availability_90', 'availability_365',
    'minimum_minimum_nights', 'maximum_minimum_nights', 'minimum_maximum_nights',
    'maximum_maximum_nights', 'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm',
    'availability_eoy', 'calculated_host_listings_count_shared_rooms'
]

# %%
df.drop(columns=columnas_remover, inplace=True)

# %%
#Verificamos información del DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10168 entries, 0 to 10167
# Data columns (total 52 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   last_scraped                                  10168 non-null  object
#  1   name                                          10168 non-null  object
#  2   host_name                                     10164 non-null  object
#  3   host_since                                    10164 non-null  object
#  4   host_location                                 9024 non-null   object
#  5   host_response_time                            6640 non-null   object
#  6   host_response_rate                            6640 non-null   object
#  7   host_acceptance_rate                          7937 non-null   object
#  8   host_is_superhost                             10069 non-null  object
# ...

# %%
#Convertir array a CSV, parte D
df.to_csv("Amsterdam.csv")

# %%
# Parte a
# Acceder a más de una Columna (Array 2D)
columnas1 = df[['host_name', 'host_since', 'neighbourhood', 'property_type', 'room_type', 'price']] #pueden ser consecutivas o no consecutivas
columnas1
# Out:
#          host_name  host_since                          neighbourhood  \
# 0             Flip  2010-03-23  Amsterdam, North Holland, Netherlands
# 1            Edwin  2010-05-13  Amsterdam, North Holland, Netherlands
# 2            Edwin  2010-05-13  Amsterdam, North Holland, Netherlands
# 3              Jan  2010-08-08  Amsterdam, Noord-Holland, Netherlands
# 4             Ivar  2010-08-24                                    NaN
# ...            ...         ...                                    ...
# 10163  Mirte Renée  2025-06-06                                    NaN
# 10164    Willemijn  2013-06-29                                    NaN
# 10165         Anna  2016-02-10                                    NaN
# 10166       Hedwig  2024-05-06                                    NaN
# 10167        Dario  2022-03-16                                    NaN
#
#                      property_type        room_type    price
# 0        Private room in houseboat     Private room  $132.00
# ...

# %%
columnas1.to_csv("ParteD.csv")

# %%
filas_a_seleccionar = df.iloc [[1]+[50] + list(range(100, 200)) + [499]+[500]+[605]+[1500]+[8000]+[10000], :]
filas_a_seleccionar
# Out:
#       last_scraped                                               name  \
# 1       2025-06-17                            Comfortable double room
# 50      2025-06-17  *historic centre* *bright* *canal view* *Jordaan*
# 100     2025-06-17                Your own cottage in the countryside
# 101     2025-06-17  Light, spacious apartment in cool Westerpark area
# 102     2025-06-17  Beautiful and spacious apartment with big rooftop
# ...            ...                                                ...
# 500     2025-06-17                Charming apartment in Museumquarter
# 605     2025-06-17         Ruim nieuwbouw appartement boven De Hallen
# 1500    2025-06-17     Charming apartment in Amsterdam's canal house!
# 8000    2025-06-17                      Luxurious 3-bedroom apartment
# 10000   2025-06-17                         Canal View & Pillow Dreams
#
#                     host_name  host_since           host_location  \
# ...

# %%
filas_a_seleccionar.to_csv("ParteB.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10168 entries, 0 to 10167
# Data columns (total 52 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   last_scraped                                  10168 non-null  object
#  1   name                                          10168 non-null  object
#  2   host_name                                     10164 non-null  object
#  3   host_since                                    10164 non-null  object
#  4   host_location                                 9024 non-null   object
#  5   host_response_time                            6640 non-null   object
#  6   host_response_rate                            6640 non-null   object
#  7   host_acceptance_rate                          7937 non-null   object
#  8   host_is_superhost                             10069 non-null  object
# ...

# %%
pd.options.display.max_rows = None

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10168 entries, 0 to 10167
# Data columns (total 52 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   last_scraped                                  10168 non-null  object
#  1   name                                          10168 non-null  object
#  2   host_name                                     10164 non-null  object
#  3   host_since                                    10164 non-null  object
#  4   host_location                                 9024 non-null   object
#  5   host_response_time                            6640 non-null   object
#  6   host_response_rate                            6640 non-null   object
#  7   host_acceptance_rate                          7937 non-null   object
#  8   host_is_superhost                             10069 non-null  object
# ...

# %%
filas_clumns = df.iloc[ [125]+[252]+ list(range(300, 500)) + [605]+[1500] , [4]+[7]+[23]+[27]+[46]] 
filas_clumns
# Out:
#                              host_location host_acceptance_rate  bathrooms  \
# 125                 Amsterdam, Netherlands                  92%        1.0
# 252                 Amsterdam, Netherlands                 100%        1.5
# 300                 Amsterdam, Netherlands                  24%        NaN
# 301                 Amsterdam, Netherlands                  92%        1.0
# 302                 Amsterdam, Netherlands                  NaN        NaN
# 303                 Amsterdam, Netherlands                 100%        1.5
# 304                 Amsterdam, Netherlands                 100%        1.0
# 305                 Amsterdam, Netherlands                  NaN        NaN
# 306   Ouderkerk aan de Amstel, Netherlands                  21%        1.0
# 307                 Amsterdam, Netherlands                  NaN        NaN
# 308                 Amsterdam, Netherlands                  91%        1.0
# ...

# %%
filas_columns.to_csv("ParteC.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 filas_columns.to_csv("ParteC.csv")
#
# NameError: name 'filas_columns' is not defined
